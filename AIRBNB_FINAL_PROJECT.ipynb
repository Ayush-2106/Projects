# %%
# !git clone 'https://github.com/HarshvardhanSingh-13/Datasets'
# Out:
# fatal: destination path 'Datasets' already exists and is not an empty directory.

# %% [markdown]
# # 1) Overall Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Datasets/Airbnb/airbnb_v2.csv')

# %%
df
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 1               1  50891766
# 2               2  50699164
# 3               3  49871422
# 4               4  51245886
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...                                                  ...    ...     ...
# 12800            Brown Dome House No. 3, full of healing   4.94      16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12805 entries, 0 to 12804
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    12805 non-null  int64
#  1   id            12805 non-null  int64
#  2   name          12805 non-null  object
#  3   rating        12805 non-null  object
#  4   reviews       12805 non-null  object
#  5   host_name     12797 non-null  object
#  6   host_id       12805 non-null  float64
#  7   address       12805 non-null  object
#  8   features      12805 non-null  object
#  9   amenities     12805 non-null  object
#  10  safety_rules  12805 non-null  object
#  11  hourse_rules  12805 non-null  object
#  12  img_links     12805 non-null  object
#  13  price         12805 non-null  int64
#  14  country       12805 non-null  object
#  15  bathrooms     12805 non-null  int64
#  16  beds          12805 non-null  int64
#  17  guests        12805 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0            id       host_id         price     bathrooms  \
# count  12805.000000  1.280500e+04  1.280500e+04  1.280500e+04  12805.000000
# mean    6402.000000  7.525187e+16  1.638192e+08  1.769780e+04      1.874424
# std     3696.629433  2.007933e+17  1.413622e+08  4.569364e+04      2.091399
# min        0.000000  1.313100e+04  2.303900e+04  3.930000e+02      0.000000
# 25%     3201.000000  2.023958e+07  3.700032e+07  3.994000e+03      1.000000
# 50%     6402.000000  3.682229e+07  1.256459e+08  8.175000e+03      1.000000
# 75%     9603.000000  4.999760e+07  2.639623e+08  1.606200e+04      2.000000
# max    12804.000000  7.017905e+17  4.758973e+08  1.907963e+06     50.000000
#
#                beds        guests        toiles      bedrooms       studios
# count  12805.000000  12805.000000  12805.000000  12805.000000  12805.000000
# mean       3.316751      5.213745      0.019211      2.136041      0.023585
# ...

# %%
df['safety_rules']
# Out:
# 0        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1        󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4        󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#                                ...
# 12800    󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 12801    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 12802    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 12803    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 12804    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
# Name: safety_rules, Length: 12805, dtype: object

# %%
df['img_links'][0]
# Out:
# 'https://a0.muscache.com/im/pictures/a5da5cb7-cac8-488f-85b1-a0dd78b28a86.jpg?im_w=720 https://a0.muscache.com/im/pictures/9aa4bc71-de8e-444a-b9fa-c2679a71a059.jpg?im_w=720 https://a0.muscache.com/im/pictures/81c2d325-fc04-40da-852f-9490df74b62b.jpg?im_w=720 https://a0.muscache.com/im/pictures/cf7f3f57-8a00-4397-acea-c891760d4b2f.jpg?im_w=720 https://a0.muscache.com/im/pictures/0fc82edc-c539-453b-8a46-268c988530fc.jpg?im_w=720 https://a0.muscache.com/im/pictures/54e427bb-9cb7-4a81-94cf-78f19156faad.jpg'

# %%
df.head(2)
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
#
#   rating reviews  host_name      host_id                   address  \
# 0   4.71      64  Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0      Fatih  386223873.0      Kaş, Antalya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
#
#                                            amenities  ... price  country  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...  ...  8078   Turkey
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...  ...  4665   Turkey
#
#   bathrooms  beds guests  toiles  bedrooms  studios              checkin  \
# 0         1     1      2       0         2        0             Flexible
# ...

# %%
df.tail(2)
# Out:
#        Unnamed: 0        id                                              name  \
# 12803       12803   8006146    WisDOME - Mentigi Bay Village - Gilis - Lombok
# 12804       12804  40547903  Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]
#
#       rating reviews host_name      host_id  \
# 12803   4.86       7   Cempaka     718423.0
# 12804   4.85      13      Achy  246470880.0
#
#                                            address  \
# 12803  Gunung Sari, Nusa Tenggara Barat, Indonesia
# 12804                        Uruma, Okinawa, Japan
#
#                                        features  \
# 12803  8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 12804      5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  ...  price  \
# 12803  Kitchen,Wifi,Dedicated workspace,Free parking ...  ...  42262
# 12804  Sea view,Beach access – Beachfront,Kitchen,Wif...  ...   9909
#
#           country bathrooms  beds guests  toiles  bedrooms  studios  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'rating', 'reviews', 'host_name', 'host_id',
#        'address', 'features', 'amenities', 'safety_rules', 'hourse_rules',
#        'img_links', 'price', 'country', 'bathrooms', 'beds', 'guests',
#        'toiles', 'bedrooms', 'studios', 'checkin', 'checkout'],
#       dtype='object')

# %%
df['country'] == 'India'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12800    False
# 12801    False
# 12802    False
# 12803    False
# 12804    False
# Name: country, Length: 12805, dtype: bool

# %%
df[df['country'] == 'India']
# Out:
#       Unnamed: 0                  id  \
# 1646        1646            38687195
# 1665        1665            40643691
# 1671        1671            38829491
# 1810        1810            49052782
# 2332        2332            51254294
# 2356        2356            13387548
# 2364        2364            12919177
# 3198        3198  619016314383105343
# 6003        6003            15526157
# 6197        6197            48798026
# 6541        6541  677928164637144798
# 6661        6661  589394294839217050
# 9705        9705            21115776
#
#                                                    name rating reviews  \
# 1646   The Shilaroo Project- a unique mountain homestay    New       2
# 1665  The Shilaroo Project - a unique mountain homestay   4.88       8
# 1671  The Shilaroo Project - a unique mountain homestay    4.8      10
# 1810  Leap Of Nature -Mountain View & Riverside-Home...   4.94      16
# 2332     Charming, chillout houseboat in great location    New       1
# ...

# %%
df[(df['country'] == 'India') & (df['price'] < 1000)]
# Out:
#       Unnamed: 0        id                      name rating reviews  \
# 6197        6197  48798026  Cozy Comfortable Stay!!!    New       0
#
#         host_name      host_id address  \
# 6197  Jai Guru Ji  372271238.0   India
#
#                                          features  \
# 6197  2 guests,1 bedroom,1 bed,1 private bathroom
#
#                                               amenities  ... price country  \
# 6197  Wifi,Free parking on premises,TV,Air condition...  ...   923   India
#
#      bathrooms  beds guests  toiles  bedrooms  studios               checkin  \
# 6197         1     1      2       0         1        0   11 00 am - 11 00 pm
#
#       checkout
# 6197       NaN
#
# [1 rows x 23 columns]

# %%
## Filtered data where country is Turkey and number of bedroom > 1 and the name of owners of first 5

# %%
df[(df['country'] == 'Turkey') & (df['bedrooms'] >=1)].head(5)['name']
# Out:
# 70                                 Sea View Villa in Kas
# 5862      (105) King Cave Suite (Mysterious Cave Suites)
# 5885    (107) Deluxe Cave Suite (Mysterious Cave Suites)
# Name: name, dtype: object

# %%
## for Japan
df[(df['country'] == 'Japan') & (df['bedrooms'] >=1 )].head(5)['name']
# Out:
# 6925    4BD/11PPL Only one group a day - "Casa BUDONO-KI"
# Name: name, dtype: object

# %%
df['country'].value_counts()
# Out:
# country
#  India         2766
#  Italy         1186
#  Greece         885
#  Thailand       677
#  Turkey         519
#                ...
#  Kosovo           1
#  Guatemala        1
#  St Martin        1
# Puerto Rico       1
#  Senegal          1
# Name: count, Length: 148, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_name          8
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %%
df.dropna(subset = 'host_name')
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 1               1  50891766
# 2               2  50699164
# 3               3  49871422
# 4               4  51245886
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...                                                  ...    ...     ...
# 12800            Brown Dome House No. 3, full of healing   4.94      16
# ...

# %% [markdown]
# # 2) Column Wise Exploration

# %%
df
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 1               1  50891766
# 2               2  50699164
# 3               3  49871422
# 4               4  51245886
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...                                                  ...    ...     ...
# 12800            Brown Dome House No. 3, full of healing   4.94      16
# ...

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#              id                                               name rating  \
# 0      49849504                                     Perla bungalov   4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...    New
# 2      50699164                                  cottages sataplia   4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.0
# 4      51245886                                      Bungalov Ev 2    New
# ...         ...                                                ...    ...
# 12800  44697740            Brown Dome House No. 3, full of healing   4.94
# 12801  29975283       Bubble Hotel Ubud with Bathtub under the Sky   4.67
# 12802  32977697                                   Paradise Eco Hub   4.67
# 12803   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86
# 12804  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85
#
#       reviews    host_name      host_id  \
# ...

# %% [markdown]
# # ID

# %%
len(df['address'])
# Out:
# 12805

# %%
df['id'].nunique()
# Out:
# 12805

# %% [markdown]
# # Name

# %%
df['name'].value_counts()
# Out:
# name
# Dorm Bed in Traditional Ger - Mongol Ujin Camp                               6
# Haveli  - Large room in Art & Book filled mansion!                           5
# The goat village Nagtibba By Bakri Chhap                                     4
# InnerX-Stay, Floating Homestay in Lan Ha bay                                 4
# Comfort room with breakfast included                                         3
#                                                                             ..
# Lalie Guest House - Complete House                                           1
# ✿Surfer's Dream✿                                                             1
# Stunning modern 3 bedroom apartment in Netanya with spectacular sea views    1
# Green Garden                                                                 1
# Charming & comfortable bungalow                                              1
# Name: count, Length: 12716, dtype: int64

# %%
df['name'].nunique()
# Out:
# 12716

# %% [markdown]
# # Rating

# %%
df[df['rating'] == 'New']
# Out:
#                        id                                               name  \
# 1                50891766  Authentic Beach Architect Sheltered Villa with...
# 4                51245886                                      Bungalov Ev 2
# 5                48650769                      CasaMia White Suite Treehouse
# 6                50765985                                     Ladin Bungalow
# 7                40947216                                     Lavender House
# ...                   ...                                                ...
# 12790            53925646  Dome2 Rooms Dome2 in a home where you can esca...
# 12791            41257160    Romantic stay at Tent galaxy villa with jacuzzi
# 12793  621201623913222432        Kintamani Glamping Black Lava camp Potato 2
# 12795            44045739                                       Tambu a mare
# 12799  640474109823176234                            Holiday home, Plemmirio
#
# ...

# %%
## Replace
df[df['rating'] == 'New'].replace('New', 0)
# Out:
# /tmp/ipython-input-418869289.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[df['rating'] == 'New'].replace('New', 0)
#                        id                                               name  \
# 1                50891766  Authentic Beach Architect Sheltered Villa with...
# 4                51245886                                      Bungalov Ev 2
# 5                48650769                      CasaMia White Suite Treehouse
# 6                50765985                                     Ladin Bungalow
# 7                40947216                                     Lavender House
# ...                   ...                                                ...
# 12790            53925646  Dome2 Rooms Dome2 in a home where you can esca...
# ...

# %%
## Creating a new data framing for removing the values which doesnot have
## 'new' in them and putting those values in new dataframe.
df_= df[df['rating'] != 'New']

# %%
## reseting the index means the numbering which so it is shown constant without
## missig numbers.
df_.reset_index(inplace = True)

# %%
df['rating'].unique()
# Out:
# array(['4.71', 'New', '4.85', '5.0', '4.67', '4.97', '4.89', '4.83',
#        '4.87', '4.9', '4.75', '4.76', '4.84', '4.79', '4.82', '4.93',
#        '4.96', '4.6', '4.64', '4.68', '4.8', '4.69', '4.58', '4.63',
#        '4.91', '4.88', '4.94', '4.92', '4.86', '4.78', '4.57', '4.99',
#        '4.98', '4.74', '4.7', '4.77', '4.72', '4.73', '4.95', '4.81',
#        '4.53', '4.59', '4.62', '4.61', '4.51', '4.54', '4.56', '4.65',
#        '4.55', '4.66', '4.52', '4.5', '4.33', '4.26', '3.33', '4.2',
#        '4.0', '4.48', '4.38', '3.0', '4.49', '4.28', '4.45', '4.25',
#        '4.36', '4.46', '4.44', '4.43', '3.75', '3.25', '4.13', '4.15',
#        '3.88', '4.29', '4.4', '3.5', '4.31'], dtype=object)

# %%
# the values were in string or were as object, so in this we changed the type
# from string to float
df['rating'] = df['rating'].replace('New', np.nan)
df['rating'] = df['rating'].astype(float)

# %%
df['rating'].mean()
# Out:
# np.float64(4.857475195517684)

# %%
## To find the countries
for i in df['country'].unique():
  print(i)
# Out:
#  Turkey
#  Georgia
#  Vietnam
#  Thailand
#  South Korea
#  India
#  Philippines
#  Japan
#  Lebanon
#  Taiwan
#  Israel
# Turkey
#  Armenia
#  Cyprus
#  Lithuania
#  Slovakia
#  Denmark
#  Germany
#  Indonesia
#  Poland
#  Romania
#  Greece
#  Ukraine
#  Hungary
#  Albania
#  Bulgaria
#  Malaysia
#  Montenegro
#  Slovenia
#  Czechia
#  Sweden
#  Austria
#  Croatia
#  Tanzania
#  Italy
#  Sri Lanka
# Philippines
#  Bosnia & Herzegovina
# Montenegro
#  Kenya
#  Serbia
#  Seychelles
#  Finland
#  Norway
#  Iceland
#  Greenland
#  United States
#  Canada
#  Svalbard & Jan Mayen
# Iceland
#  France
#  Australia
#  Morocco
#  Egypt
#  South Africa
#  Spain
#  United Arab Emirates
#  United Kingdom
#  Pakistan
# Thailand
#  Nepal
# Sri Lanka
#  Singapore
#  Cambodia
#  Azerbaijan
#  Estonia
#  Latvia
#  Costa Rica
#  Netherlands
#  Portugal
#  New Zealand
#  Panama
#  Mexico
#  Peru
#  Chile
#  Belize
# Panama
#  Colombia
#  Switzerland
#  Ireland
#  Bolivia
# India
# United Kingdom
# ...

# %%
# Trim is called Strip in Python
# To remove the unnecessary spaces
df['cleaned_country'] = df['country'].str.strip()

# %%
df
# Out:
#              id                                               name  rating  \
# 0      49849504                                     Perla bungalov    4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...     NaN
# 2      50699164                                  cottages sataplia    4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.00
# 4      51245886                                      Bungalov Ev 2     NaN
# ...         ...                                                ...     ...
# 12800  44697740            Brown Dome House No. 3, full of healing    4.94
# 12801  29975283       Bubble Hotel Ubud with Bathtub under the Sky    4.67
# 12802  32977697                                   Paradise Eco Hub    4.67
# 12803   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok    4.86
# 12804  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]    4.85
#
#       reviews    host_name      host_id  \
# ...

# %%
df[df['cleaned_country'] == 'Japan']
# Out:
#                        id                                               name  \
# 39               21082489                               LOGIN OKINAWA -wood-
# 51     679805160588663838                             LOGIN OKINAWA -plants-
# 54               34029409                  恩纳村的打卡圣地网红海景小木屋Cinderella J House
# 1191              3209511                           Beach Side House alohana
# 1204             19256665  A small house in the forest / Relaxing environ...
# ...                   ...                                                ...
# 12745  585129042504781524                URUMA DOME Earth4 & Mars5 MK309,310
# 12761            49630137  Comfort Privacy and Nature with a View.  Pets OK!
# 12788            43681892  Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven2]
# 12797            44080105  Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seve...
# 12804            40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]
#
# ...

# %%
df['address'].str.split(',').str[-2].str.strip()
# Out:
# 0                      Kocaeli
# 1                      Antalya
# 2                      Imereti
# 3                      Sakarya
# 4                      Sakarya
#                  ...
# 12800    South Jeolla Province
# 12801                  Gianyar
# 12802                   Kabale
# 12803      Nusa Tenggara Barat
# 12804                  Okinawa
# Name: address, Length: 12805, dtype: object

# %%
japan_df = df[(df['cleaned_country'] == 'Japan') & (df['bedrooms'] > 1)]
display(japan_df.head(5)['host_name'])
# Out:
# 39      LoginOkinawa
# 51      LoginOkinawa
# 54            Kiyomi
# 1226           Saori
# 1229           Keiko
# Name: host_name, dtype: object

# %%
## Count of the countries
for i in df['cleaned_country'].unique():
  print(i, len(df[df['cleaned_country'] == i]))
# Out:
# Turkey 522
# Georgia 371
# Vietnam 103
# Thailand 683
# South Korea 226
# India 2779
# Philippines 199
# Japan 322
# Lebanon 23
# Taiwan 312
# Israel 137
# Armenia 6
# Cyprus 20
# Lithuania 25
# Slovakia 14
# Denmark 29
# Germany 261
# Indonesia 262
# Poland 134
# Romania 108
# Greece 889
# Ukraine 42
# Hungary 27
# Albania 4
# Bulgaria 53
# Malaysia 105
# Montenegro 12
# Slovenia 36
# Czechia 60
# Sweden 150
# Austria 63
# Croatia 145
# Tanzania 8
# Italy 1187
# Sri Lanka 275
# Bosnia & Herzegovina 6
# Kenya 56
# Serbia 56
# Seychelles 9
# Finland 138
# Norway 211
# Iceland 34
# Greenland 1
# United States 191
# Canada 37
# Svalbard & Jan Mayen 1
# France 466
# Australia 25
# Morocco 377
# Egypt 70
# South Africa 39
# Spain 66
# United Arab Emirates 52
# United Kingdom 313
# Pakistan 11
# Nepal 38
# Singapore 5
# Cambodia 19
# Azerbaijan 4
# Estonia 40
# Latvia 21
# Costa Rica 4
# Netherlands 97
# Portugal 44
# New Zealand 7
# Panama 13
# Mexico 25
# Peru 4
# Chile 8
# Belize 14
# ...

# %%
df['bathrooms'].value_counts()
# Out:
# bathrooms
# 1     8000
# 2     1917
# 3      902
# 4      590
# 0      446
# 5      306
# 6      215
# 8      121
# 7      106
# 9       50
# 10      40
# 12      27
# 11      22
# 13      16
# 14       9
# 15       8
# 21       4
# 17       4
# 24       4
# 22       3
# 18       3
# 16       3
# 50       2
# 23       2
# 38       1
# 27       1
# 25       1
# 30       1
# 20       1
# Name: count, dtype: int64

# %%
df[df['bathrooms'] == 50]
# Out:
#             id                                       name  rating reviews  \
# 1111  47891864                    Inn resort garden house     NaN       1
# 4351  15217006  Classic Tour Services Nile Cruise booking     NaN       0
#
#       host_name      host_id                                    address  \
# 1111  Chindanai  321081514.0  Ban Luang, Chang Wat Chiang Mai, Thailand
# 4351      Hatem   96686906.0           Luxor , Luxor Governorate, Egypt
#
#                                         features  \
# 1111   16 guests,50 bedrooms,2 beds,50 bathrooms
# 4351  16 guests,50 bedrooms,50 beds,50 bathrooms
#
#                                               amenities  \
# 1111  Wifi,Free parking on premises,Pets allowed,TV,...
# 4351  Kitchen,Wifi,Free parking on premises,Pool,Sha...
#
#                                            safety_rules  ...    country  \
# 1111  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...   Thailand
# ...

# %%
for i in df['bathrooms'].unique():
  print(i, len(df[df['bathrooms'] == i]))
# Out:
# 1 8000
# 2 1917
# 3 902
# 4 590
# 0 446
# 5 306
# 6 215
# 8 121
# 7 106
# 9 50
# 10 40
# 50 2
# 12 27
# 24 4
# 17 4
# 21 4
# 11 22
# 18 3
# 16 3
# 38 1
# 13 16
# 27 1
# 25 1
# 15 8
# 23 2
# 14 9
# 22 3
# 30 1
# 20 1

# %% [markdown]
# # Reviews

# %%
df['reviews'].value_counts()
# Out:
# reviews
# 0      2393
# 1      1131
# 2       707
# 3       464
# 4       324
#        ...
# 524       1
# 257       1
# 510       1
# 359       1
# 267       1
# Name: count, Length: 409, dtype: int64

# %%
# Check for non-integer values in 'reviews' column
non_int_reviews = df[~df['reviews'].str.isdigit()]['reviews'].unique()
if len(non_int_reviews) > 0:
    print(f"Found non-integer values in 'reviews': {non_int_reviews}")
    # Decide how to handle these values, e.g., replace with NaN or drop rows
    # For now, I'll print them and stop the conversion.
else:
    df['reviews'] = df['reviews'].astype(int)
    print("'reviews' column converted to integer type.")
# Out:
# Found non-integer values in 'reviews': ['1,003']

# %%
df['reviews'] = df['reviews'].astype(str)
df['reviews'] = df['reviews'].str.replace(',', '')
df['reviews'] = df['reviews'].astype(int)

# %%
df['reviews'].mean()
# Out:
# np.float64(36.1400234283483)

# %% [markdown]
# # Features

# %%
df['features']
# Out:
# 0                2 guests,2 bedrooms,1 bed,1 bathroom
# 1              4 guests,2 bedrooms,2 beds,2 bathrooms
# 2                4 guests,1 bedroom,3 beds,1 bathroom
# 3                4 guests,1 bedroom,2 beds,1 bathroom
# 4                 2 guests,1 bedroom,1 bed,1 bathroom
#                              ...
# 12800                            4 guests,8 bathrooms
# 12801       2 guests,1 bedroom,1 bed,Toilet with sink
# 12802    2 guests,1 bedroom,2 beds,1 private bathroom
# 12803        8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 12804            5 guests,1 bedroom,2 beds,1 bathroom
# Name: features, Length: 12805, dtype: object

# %%
# df[df['features'].str.split(',').str.len() == 2]
# or
df[df['features'].str.split(',').str.len() == 4]['features']
# Out:
# 0                2 guests,2 bedrooms,1 bed,1 bathroom
# 1              4 guests,2 bedrooms,2 beds,2 bathrooms
# 2                4 guests,1 bedroom,3 beds,1 bathroom
# 3                4 guests,1 bedroom,2 beds,1 bathroom
# 4                 2 guests,1 bedroom,1 bed,1 bathroom
#                              ...
# 12799          8 guests,4 bedrooms,4 beds,2 bathrooms
# 12801       2 guests,1 bedroom,1 bed,Toilet with sink
# 12802    2 guests,1 bedroom,2 beds,1 private bathroom
# 12803        8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 12804            5 guests,1 bedroom,2 beds,1 bathroom
# Name: features, Length: 12155, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'name', 'rating', 'reviews', 'host_name', 'host_id', 'address',
#        'features', 'amenities', 'safety_rules', 'hourse_rules', 'img_links',
#        'price', 'country', 'bathrooms', 'beds', 'guests', 'toiles', 'bedrooms',
#        'studios', 'checkin', 'checkout', 'cleaned_country'],
#       dtype='object')

# %% [markdown]
# # Amenities

# %%
df['amenities']
# Out:
# 0        Mountain view,Valley view,Lake access,Kitchen,...
# 1        Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2        Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3        Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4        Kitchen,Wifi,Free parking on premises,TV,Air c...
#                                ...
# 12800    Kitchen,Wifi,Free parking on premises,Private ...
# 12801    Wifi,Free on-street parking,Air conditioning,G...
# 12802    Wifi,Breakfast,Long-term stays allowed,Unavail...
# 12803    Kitchen,Wifi,Dedicated workspace,Free parking ...
# 12804    Sea view,Beach access – Beachfront,Kitchen,Wif...
# Name: amenities, Length: 12805, dtype: object

# %%
# df[df['amenities'].str.split(',').str.len() == 2]
# or
df[df['amenities'].str.split(',').str.len() == 3]['amenities']
# Out:
# 741      Long-term stays allowed,Unavailable: Carbon mo...
# 1138     Long-term stays allowed,Unavailable: Carbon mo...
# 1219     Long-term stays allowed,Unavailable: Carbon mo...
# 1345     Free parking on premises,Long-term stays allow...
# 1515     Free parking on premises,Air conditioning,Long...
# 2567     Long-term stays allowed,Unavailable: Carbon mo...
# 2928               Wifi,Hair dryer,Long-term stays allowed
# 2985     Free parking on premises,Shared pool,Long-term...
# 3052     Free parking on premises,Long-term stays allow...
# 3709     Long-term stays allowed,Unavailable: Carbon mo...
# 3949     Long-term stays allowed,Unavailable: Carbon mo...
# 4359     Kitchen,Long-term stays allowed,Unavailable: C...
# 4393     Long-term stays allowed,Unavailable: Carbon mo...
# 4424     Long-term stays allowed,Unavailable: Carbon mo...
# 4455     Air conditioning,Long-term stays allowed,Unava...
# 4497     Long-term stays allowed,Unavailable: Carbon mo...
# ...

# %%
## There is a spelling mistake in the one of the columns.
df[df['hourse_rules'].str.split(',').str.len() == 2]
# Out:
#                        id                                               name  \
# 32               50458442  Bungalow Holiday Villa Gen with Private Pool a...
# 63     636562135731372477                    4-Person Villa with Nature View
# 82     562138091801957973  Sleeps 2 with a private pool and a jacuzzi in ...
# 91               51120664               HAERI • (H1) • Utsera Cabins • Racha
# 103    618591377457733542           Enjoying a peaceful vacation is personal
# ...                   ...                                                ...
# 12714  632555985266496734          Small geodesic forest dome for two people
# 12718  579492879082561857  Adorable A/c  Luxury Geodesic Dome with a Dip ...
# 12720  617961142341439818              Nature habitat - room in nature - One
# 12726            47730398                                  Følvika Eagle Eye
# 12744  579509532534384214       Breezy hill top Bubble House with a Dip Pool
#
# ...
